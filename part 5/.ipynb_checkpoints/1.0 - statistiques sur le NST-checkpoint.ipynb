# %%
import os
import conllu
import pandas as pd

# %%
path_agregated_cvs = "/home/wran/Research/memoire/experimentations_notebooks/data/6_cvs/agregated_cvs.conllu"

# %%
with open(path_agregated_cvs, 'r') as infile:
    parsed_conllu = conllu.parse(infile.read())

# %%
n_true_sequences = {}
n_true_tokens = {}

properties = ['head', 'deprel', 'pos', 'LA']
for property_ in properties:
    n_true_sequences[property_] = 0
    n_true_tokens[property_] = 0

# %%
n_total_sequences = 0
n_total_tokens = 0
n_true_sequences = {}
n_true_tokens = {}

properties = ['head', 'deprel', 'pos', 'LA']
for property_ in properties:
    n_true_sequences[property_] = 0
    n_true_tokens[property_] = 0
    
df_labels = []
for property_ in properties:
    df_labels += ["{}_{}".format(property_, truthiness) for truthiness in ["true", "false"]]    
df = pd.DataFrame(columns=["sequence_len"] + df_labels)
    
for i, sequence in enumerate(parsed_conllu):
    sequence_true = {}
    for property_ in properties:
        sequence_true[property_] = 0
        
    sequence_len = (len(sequence))
    
    for token in sequence:
        head_pred = int(token['misc']['head_MST'])
        head_true = int(token['head'])
        
        deprel_pred = (token['misc']['deprel_main_pred'])
        deprel_true = (token['deprel'])
        
        pos_pred = token['upos']
        pos_true = (token['misc']['upostag'])

        
        head_correct, deprel_correct = False, False
        if head_pred == head_true:
            sequence_true['head'] += 1
            head_correct = True
        
        if deprel_pred.replace("@", ":") == deprel_true.replace("@", ":"):
            sequence_true['deprel'] += 1
            deprel_correct = True
            
        if (head_correct) & (deprel_correct):
            sequence_true['LA'] += 1
            
        if pos_pred == pos_true: 
            sequence_true['pos'] += 1
    
    dict_sequence = {}
    
    for property_ in properties:
        n_true_sequences[property_] += int(sequence_true[property_] == sequence_len)
        n_true_tokens[property_] += sequence_true[property_]
        dict_sequence["{}_true".format(property_)] = sequence_true[property_]
        dict_sequence["{}_false".format(property_)] = sequence_len - sequence_true[property_]
    
    n_total_sequences += 1
    n_total_tokens += sequence_len
    dict_sequence["sequence_len"] = sequence_len
    
    df = df.append(dict_sequence, ignore_index=True)
    
for property_ in properties:
    print(property_)
    print("{:.1f}% sentences correct ({}/{})".format(100*n_true_sequences[property_]/n_total_sequences, n_true_sequences[property_], n_total_sequences))
    print("{:.1f}% tokens correct ({}/{})".format(100*n_true_tokens[property_]/n_total_tokens, n_true_tokens[property_], n_total_tokens))
    print()
# Out:
# head
# 65.5% sentences correct (5410/8259)
# 94.2% tokens correct (123475/131042)
#
# deprel
# 54.1% sentences correct (4469/8259)
# 94.1% tokens correct (123250/131042)
#
# pos
# 65.4% sentences correct (5400/8259)
# 96.8% tokens correct (126862/131042)
#
# LA
# 46.8% sentences correct (3865/8259)
# 90.5% tokens correct (118555/131042)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
sns.set(color_codes=True)

# %%
df["sequence_len_copy"] = df['sequence_len']

# %%
df_groupby = df.groupby("sequence_len").sum()
for property_ in properties :
    df_groupby['ratio_{}_false'.format(property_)] = df_groupby['{}_false'.format(property_)]/df_groupby['sequence_len_copy']
df_groupby
# Out:
#               head_true  head_false  deprel_true  deprel_false  pos_true  \
# sequence_len
# 2                   320           0          318             2       193
# 3                   731          28          726            33       643
# 4                  1200          48         1186            62      1164
# 5                  1787          58         1759            86      1753
# 6                  2684          82         2621           145      2669
# ...                 ...         ...          ...           ...       ...
# 102                  90          12           99             3        96
# 105                  95          10          102             3       100
# 111                  94          17          102             9       102
# 131                 104          27          113            18       125
# 135                 100          35          115            20       122
#
#               pos_false  LA_true  LA_false  sequence_len_copy  \
# sequence_len
# 2                   127      318         2                320
# 3                   116      717        42                759
# 4                    84     1162        86               1248
# 5                    92     1732       113               1845
# 6                    97     2578       188               2766
# ...                 ...      ...       ...                ...
# 102                   6       87        15                102
# 105                   5       93        12                105
# 111                   9       93        18                111
# 131                   6       97        34                131
# 135                  13       95        40                135
#
#               ratio_head_false  ratio_deprel_false  ratio_pos_false  \
# sequence_len
# 2                     0.000000            0.006250         0.396875
# 3                     0.036891            0.043478         0.152833
# 4                     0.038462            0.049679         0.067308
# 5                     0.031436            0.046612         0.049864
# 6                     0.029646            0.052422         0.035069
# ...                        ...                 ...              ...
# 102                   0.117647            0.029412         0.058824
# 105                   0.095238            0.028571         0.047619
# 111                   0.153153            0.081081         0.081081
# 131                   0.206107            0.137405         0.045802
# 135                   0.259259            0.148148         0.096296
#
#               ratio_LA_false
# sequence_len
# 2                   0.006250
# 3                   0.055336
# 4                   0.068910
# 5                   0.061247
# 6                   0.067968
# ...                      ...
# 102                 0.147059
# 105                 0.114286
# 111                 0.162162
# 131                 0.259542
# 135                 0.296296
#
# [89 rows x 13 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
x_lim=80

# %%
import matplotlib as mpl
import brewer2mpl
# brewer2mpl.get_map args: set name  set type  number of colors
bmap = brewer2mpl.get_map('Set1', 'qualitative', 4)
colors = bmap.mpl_colors

params = {
   'axes.labelsize': 8,
 #  'text.fontsize': 8,
   'legend.fontsize': 10,
   'xtick.labelsize': 10,
   'ytick.labelsize': 10,
   'text.usetex': False,
   'figure.figsize': [10, 5]
   }
mpl.rcParams.update(params)

# %%
x_lim = [3, 80]
x = df_groupby.reset_index()['sequence_len'][x_lim[0]:x_lim[1]].to_numpy().reshape(-1, 1)

plt.figure(figsize=(12,8))
for i, property_ in enumerate(["head", "deprel", "pos"]):
    y = df_groupby['ratio_{}_false'.format(property_)][x_lim[0]:x_lim[1]].to_numpy().reshape(-1, 1)
    
    regressor = LinearRegression()  
    regressor.fit(x, y)
    
    plt.plot(x, y, color=colors[i], label="{}".format(property_))
    plt.plot(x, regressor.predict(x) ,color=colors[i], linestyle="dotted")

plt.title("performance de l'analyseur en fonction de la taille de la phrase")
plt.legend()
plt.xlim([x_lim[0],x_lim[1]])
plt.show()

# %%
len(sequence)
# Out:
# 12

# %%
for sequence in parsed_conllu:
    if len(sequence) < 3:
        print(sequence)
# Out:
# TokenList<ah, !//>
# TokenList<ah, !//>
# TokenList<why, ?//>
# TokenList<noting, //>
# TokenList<ehen, //>
# TokenList<ehen, !//>
# TokenList<position, !//>
# TokenList<mtschew, !//>
# TokenList<mtschew, !//>
# TokenList<mtschew, !//>
# TokenList<mtschew, !//>
# TokenList<eh, !//>
# TokenList<Jesus, !//>
# TokenList<ehn, ?//>
# TokenList<ehn, ?//>
# TokenList<ehn, !//>
# TokenList<okay, !//>
# TokenList<okay, !//>
# TokenList<okay, !//>
# TokenList<so, &//>
# TokenList<ehen, //>
# TokenList<yes, ?//>
# TokenList<hehe, //>
# TokenList<toh, //>
# TokenList<okay, //>
# TokenList<okay, //>
# TokenList<hm, //>
# TokenList<okay, //>
# TokenList<haha, //>
# TokenList<okay, !//>
# TokenList<tomorrow, ?//>
# TokenList<ehn, !//>
# TokenList<ah, !//>
# TokenList<toh, //>
# TokenList<CAC, ?//>
# TokenList<hm, //>
# TokenList<eh, //>
# TokenList<ehn, !//>
# TokenList<confirm, !//>
# TokenList<eyah, !//>
# TokenList<eyah, !//>
# TokenList<eyah, !//>
# TokenList<uhm, ?//>
# TokenList<uhum, !//>
# TokenList<no, !//>
# TokenList<all, &//>
# TokenList<haha, //>
# TokenList<fai-, &//>
# TokenList<mstchew, !//>
# TokenList<abacha, ?//>
# TokenList<ah, !//>
# TokenList<hm, //>
# TokenList<aha, !//>
# TokenList<ah, !//>
# TokenList<haha, //>
# TokenList<haha, //>
# TokenList<haha, //>
# TokenList<ha, !//>
# TokenList<ehen, !//>
# TokenList<no, !//>
# TokenList<ehen, ?//>
# TokenList<nobody, !//>
# TokenList<everyday, !//>
# TokenList<ehen, !//>
# TokenList<ehen, //>
# TokenList<Kabiru, //>
# TokenList<eh, !//>
# TokenList<aha, !//>
# TokenList<ehn, !//>
# TokenList<aha, !//>
# TokenList<toh, !//>
# TokenList<ehn, //>
# TokenList<haha, //>
# TokenList<hm, //>
# TokenList<aha, !//>
# TokenList<ah, !//>
# TokenList<hm, !//>
# TokenList<o-, //>
# TokenList<ah, !//>
# TokenList<ha, !//>
# TokenList<eh, !//>
# TokenList<hm, //>
# TokenList<shoo, !//>
# TokenList<eh, !//>
# TokenList<aha, !//>
# TokenList<haha, //>
# TokenList<ehn, !//>
# TokenList<eh, !//>
# TokenList<see, &//>
# TokenList<ha, !//>
# TokenList<haba, !//>
# TokenList<aha, !//>
# TokenList<aha, !//>
# TokenList<okay, !//>
# TokenList<aha, !//>
# TokenList<even, &//>
# TokenList<hm, //>
# TokenList<okay, //>
# TokenList<okay, !//>
# TokenList<hm, !//>
# TokenList<haba, !//>
# TokenList<hm, !//>
# TokenList<hm, //>
# TokenList<okay, //>
# TokenList<increase, !//>
# TokenList<haha, !//>
# TokenList<reorientation, //>
# TokenList<heh, !//>
# TokenList<ehen, !//>
# TokenList<ah, !//>
# TokenList<eheh, !//>
# TokenList<indomie, !//>
# TokenList<ehen, ?//>
# TokenList<ehn, ?//>
# TokenList<hey, !//>
# TokenList<hm, !//>
# TokenList<hey, !//>
# TokenList<hey, !//>
# TokenList<X, //>
# TokenList<ehen, !//>
# TokenList<o'oh, !//>
# TokenList<ehn, //>
# TokenList<eh, //>
# TokenList<eheh, !//>
# TokenList<hm, //>
# TokenList<ehen, !//>
# TokenList<ah, !//>
# TokenList<ehen, !//>
# TokenList<hm, !//>
# TokenList<heh, !//>
# TokenList<wait, !//>
# TokenList<ehen, //>
# TokenList<soup, ?//>
# TokenList<hm, //>
# TokenList<ehe, !//>
# TokenList<hm, //>
# TokenList<oh, //>
# TokenList<bye, !//>
# TokenList<bye, !//>
# TokenList<no, !//>
# TokenList<no, !//>
# TokenList<why, ?//>
# TokenList<di, &//>
# TokenList<no, //>
# TokenList<no, !//>
# TokenList<nobody, !//>
# TokenList<hm'm, !//>
# TokenList<hehe, //>
# TokenList<we, &//>
# TokenList<illusions, //>
# TokenList<hm, !//>
# TokenList<ah, !//>
# TokenList<heh, !//>
# TokenList<hm, !//>
# TokenList<imagine, !//>
# TokenList<why, ?//>
# TokenList<no, !//>
# TokenList<darkness, //>
# TokenList<disappear, //>
# TokenList<haba, !//>

# %%
list_all_deprel = []

list_failed_deprel = []
couple_all_deprel_failed = []

couple_restricted_deprel_fail = []
couple_under_specified = []
couple_over_specified = []

list_deprel_true = []
list_deprel_pred = []
list_succeed_deprel = []
list_succeed_head = []
list_token_head = []
list_token_dep = []
list_syn_dist = []
list_sequence_len = []
for i, sequence in enumerate(parsed_conllu):
    for token in sequence:
        dict_row = {}
        list_all_deprel.append(deprel_true)
        list_syn_dist.append(int(token["head"])- int(token['id']))
        list_sequence_len.append(len(sequence))
        
        deprel_pred = (token['misc']['deprel_main_pred'])
        deprel_true = (token['deprel'])
        list_deprel_true.append(deprel_true)
        list_deprel_pred.append(deprel_pred)
        
        list_token_head.append(sequence[token["head"]-1]["form"])
        list_token_dep.append(token["form"])
        if deprel_pred.replace("@", ":") != deprel_true.replace("@", ":"):
            couple_relation = "{}___{}".format(deprel_true, deprel_pred)
            if deprel_true in deprel_pred:
                couple_over_specified.append(couple_relation)
            
            elif deprel_pred in deprel_true:
                couple_under_specified.append(couple_relation)
                
            else:
                couple_restricted_deprel_fail.append(couple_relation)                
                list_failed_deprel.append(deprel_true)
                succeed_deprel = 0
            couple_all_deprel_failed.append(couple_relation)
        
        else:
            succeed_deprel = 1
        
        head_pred = int(token['misc']['head_MST'])
        head_true = int(token['head'])
        
        if head_pred == head_true:
            succeed_head = 1
        else:
            succeed_head = 0
        
        list_succeed_deprel.append(succeed_deprel)
        list_succeed_head.append(succeed_head)

# %%
data = zip(
    list_deprel_true, 
    list_deprel_pred, 
    list_succeed_deprel, 
    list_succeed_head,
    list_token_head,
    list_token_dep,
    list_syn_dist,
    list_sequence_len,
)
df_deprel = pd.DataFrame(data,columns=["deprel_true", "deprel_pred", "succeed_deprel", "succeed_head",
                                      "token_head", "token_dep", "syn_dist", 'sequence_len'])

# %%
from collections import Counter

# %% [markdown]
# On peut voir dans les trois cellules suivantes que sur nos 7500 erreurs globales de mauvais etiquettage de la fonction, 10% (700) sont liées à une sous-spécification de la fonction (mod à la place de mod:emph) et 10% sont liées à une sur-spécification (mod:emph au lieu de mod).
# Ces erreurs, qui representent 20% de nos erreures de labelisation, ne sont pas de graves erreurs mais peuvent entre autre nous aider à déceler des ambiguités d'annotations

# %%
print(len(list_all_deprel_failed))
# Out:
# 7792

# %%
print(len(list_under_specified))
Counter(list_under_specified).most_common(10)
# Out:
# 699
# [('mod:emph___mod', 128),
#  ('subj@expl___subj', 85),
#  ('mod:periph___mod', 72),
#  ('comp:obj@lvc___comp:obj', 52),
#  ('comp:obj@x___comp:obj', 34),
#  ('comp:pred@fixed___comp:pred', 34),
#  ('root@scrap___root', 33),
#  ('comp:obj@scrap___comp:obj', 26),
#  ('mod:poss___mod', 26),
#  ('det:num___det', 23)]

# %%
print(len(list_over_specified))
Counter(list_over_specified).most_common(10)
# Out:
# 638
# [('mod___mod:periph', 118),
#  ('mod___mod:poss', 99),
#  ('mod___mod:emph', 63),
#  ('subj___subj:expl', 62),
#  ('comp:obj___comp:obj:x', 40),
#  ('comp:pred___comp:pred:fixed', 39),
#  ('mod___mod:relcl', 32),
#  ('root___root:scrap', 31),
#  ('comp:obj___comp:obj:lvc', 23),
#  ('comp:obj___comp:obj:scrap', 19)]

# %%
print(len(couple_deprel_fail))
Counter(couple_deprel_fail).most_common(10)
# Out:
# 6455
# [('mod___comp:obl', 260),
#  ('mod___compound', 195),
#  ('mod___comp:obj', 169),
#  ('comp:obj___mod', 163),
#  ('comp:obl___mod', 163),
#  ('comp:obj@x___comp:aux', 148),
#  ('compound___mod', 142),
#  ('dislocated___mod:periph', 89),
#  ('mod___comp:pred', 82),
#  ('comp:pred___comp:obj', 78)]

# %%
ctr_all_deprel = Counter(list_all_deprel)
ctr_failed_deprel = Counter(list_failed_deprel)
for deprel, all_count in ctr_all_deprel.most_common():
    print(deprel, all_count, ctr_failed_deprel[deprel])
# Out:
# punct 37171 1
# comp:obj 17775 702
# subj 12180 256
# mod 9541 1004
# comp:aux 8236 194
# root 8222 364
# det 4816 45
# comp:pred 3293 311
# discourse 2551 206
# mod:periph 2439 210
# comp:obl 2048 226
# cc 1995 83
# mod@relcl 1920 117
# conj:coord 1844 297
# mod:poss 1728 23
# conj:dicto 1479 96
# dislocated 1369 275
# comp:cleft 1239 97
# compound 1094 259
# mod:emph 1076 61
# comp:obj@x 1011 245
# compound:svc 958 135
# parataxis:conj 880 61
# parataxis:obj 672 62
# unk@fixed 578 119
# flat 546 164
# compound:redup 531 25
# det:num 383 28
# compound:prt 348 43
# comp:obl@x 256 40
# subj@expl 247 1
# comp:obj@fixed 244 59
# comp:pred@fixed 229 7
# root@scrap 202 18
# conj:appos 178 39
# vocative 177 51
# mod:num 174 53
# comp:obj@scrap 168 32
# flat:foreign 159 56
# parataxis:discourse 139 57
# parataxis:parenth 119 33
# comp:obj@agent 107 27
# comp:obj@lvc 101 17
# comp:pred@agent 96 17
# unk@scrap 72 54
# parataxis:dislocated 68 40
# comp:aux@scrap 52 10
# mod:relcl 48 1
# mod@fixed 37 11
# mod:appos 29 26
# det@num 26 2
# comp:cleft@scrap 21 11
# comp:pred@scrap 20 12
# mod@scrap 20 14
# conj:dicto@scrap 18 2
# conj:coord@scrap 17 14
# comp:obl@scrap 15 6
# comp:obl@agent 12 4
# root:scrap 11 1
# subj@scrap 10 2
# parataxis:obj@scrap 7 4
# parataxis:conj@scrap 7 5
# parataxis:insert 5 5
# subj:expl 5 0
# comp:pred@x 5 2
# comp:obl@fixed 4 4
# comp:obl@lvc 4 3
# mod:dislocated 1 1
# unk 1 1
# cc@fixed 1 0
# unk:scrap 1 0
# subj:scrap 1 1
# compound:svc@scrap 1 0
# goeswith 1 1
# compound:redup@scrap 1 0
# flat@fixed 1 1
# comp:svc 1 1

# %%
ctr_all_words = Counter(list(df_deprel["token_dep"]))

# %%
ctr_all_words.most_common()
# Out:
# [('#', 10829),
#  ('//', 6867),
#  ('dey', 3817),
#  ('<', 3608),
#  ('go', 2935),
#  ('I', 2884),
#  ('di', 2630),
#  ('{', 2521),
#  ('}', 2521),
#  ('you', 2327),
#  ('na', 1823),
#  ('[', 1721),
#  ('for', 1690),
#  ('no', 1609),
#  ('|c', 1565),
#  ('sey', 1558),
#  ('||', 1522),
#  ('e', 1509),
#  ('wey', 1413),
#  ('we', 1298),
#  ('am', 1279),
#  (']', 1216),
#  ('de', 1158),
#  ('so', 1078),
#  ('con', 1045),
#  ('be', 949),
#  ('and', 919),
#  ('>+', 902),
#  ('dat', 888),
#  ('to', 864),
#  ('me', 860),
#  ('dis', 851),
#  ('dem', 816),
#  ('//=', 816),
#  ('one', 813),
#  ('my', 782),
#  ('do', 771),
#  ('don', 762),
#  ('make', 719),
#  ('of', 715),
#  ('im', 711),
#  ('now', 706),
#  ('come', 683),
#  ('if', 678),
#  ('say', 671),
#  ('get', 662),
#  ('o', 572),
#  ('like', 553),
#  ('your', 521),
#  ('|r', 509),
#  ('?//', 508),
#  ('as', 490),
#  ('!//', 476),
#  ('people', 467),
#  ('know', 451),
#  ('but', 433),
#  ('just', 427),
#  ('see', 422),
#  ('&//', 406),
#  ('eh', 403),
#  ('wetin', 395),
#  ('fit', 369),
#  ('because', 365),
#  ('tell', 361),
#  ('wan', 352),
#  ('all', 341),
#  ('talk', 330),
#  ('put', 325),
#  ('even', 322),
#  ('take', 320),
#  ('when', 314),
#  ('ehn', 313),
#  ('well', 308),
#  ('inside', 296),
#  ('carry', 294),
#  ('God', 291),
#  ('work', 291),
#  ('//]', 284),
#  ('money', 276),
#  ('us', 253),
#  ('from', 240),
#  ('some', 237),
#  ('give', 230),
#  ('una', 230),
#  ('in', 227),
#  ('on', 227),
#  ('ting', 219),
#  ('our', 217),
#  ('school', 212),
#  ('man', 210),
#  ('time', 209),
#  ('ah', 208),
#  ('small', 207),
#  ('call', 205),
#  ('how', 203),
#  ('dere', 202),
#  ('person', 187),
#  ('use', 182),
#  ('meh', 182),
#  ('buy', 182),
#  ('den', 178),
#  ('|a', 177),
#  ('house', 174),
#  ('still', 172),
#  ('two', 167),
#  ('okay', 164),
#  ('very', 159),
#  ('a', 154),
#  ('she', 153),
#  ('before', 153),
#  ('kind', 152),
#  ('or', 150),
#  ('sef', 149),
#  ('here', 148),
#  ('life', 146),
#  ('deir', 146),
#  ('tings', 141),
#  ('back', 140),
#  ('own', 138),
#  ('naim', 137),
#  ('place', 136),
#  ('enter', 135),
#  ('is', 135),
#  ('too', 134),
#  ('up', 134),
#  ('look', 133),
#  ('(', 132),
#  ('five', 131),
#  ('again', 128),
#  ('where', 128),
#  ('good', 127),
#  ('comot', 127),
#  ('reach', 125),
#  ('day', 123),
#  ('?//]', 119),
#  ('at', 117),
#  ('try', 116),
#  ('pikin', 113),
#  ('with', 113),
#  ('Nigeria', 113),
#  ('chop', 112),
#  ('start', 112),
#  ('want', 111),
#  ('help', 110),
#  ('different', 109),
#  ('hear', 107),
#  ('>', 107),
#  ('about', 106),
#  ('everybody', 105),
#  ('food', 103),
#  ('woman', 102),
#  ('dose', 101),
#  ('pass', 100),
#  ('country', 100),
#  ('why', 98),
#  ('after', 96),
#  ('!//]', 95),
#  ('three', 93),
#  ('first', 93),
#  (')', 93),
#  ('guy', 93),
#  ('naira', 92),
#  ('need', 91),
#  ('happen', 91),
#  ('ehen', 90),
#  ('soup', 90),
#  ('out', 89),
#  ('any', 89),
#  ('finish', 88),
#  ('wit', 87),
#  ('bin', 87),
#  ('thing', 86),
#  ('pay', 85),
#  ('only', 83),
#  ('better', 83),
#  ('year', 83),
#  ('name', 83),
#  ('down', 82),
#  ('mama', 81),
#  ('follow', 81),
#  ('by', 81),
#  ('way', 81),
#  ('hand', 81),
#  ('water', 81),
#  ('top', 81),
#  ('mtschew', 80),
#  ('yarn', 80),
#  ('many', 79),
#  ('bring', 78),
#  ('thousand', 77),
#  ('everyting', 76),
#  ('women', 74),
#  ('toh', 74),
#  ('anoder', 73),
#  ('stay', 73),
#  ('it', 72),
#  ('big', 71),
#  ('matter', 71),
#  ('suppose', 70),
#  ('problem', 69),
#  ('will', 69),
#  ('anyting', 68),
#  ('collect', 68),
#  ('born', 67),
#  ('today', 67),
#  ('boy', 67),
#  ('begin', 66),
#  ('oder', 66),
#  ('plenty', 66),
#  ('hundred', 66),
#  ('things', 65),
#  ('cook', 65),
#  ('last', 64),
#  ('understand', 64),
#  ('play', 64),
#  ('leave', 64),
#  ('eat', 64),
#  ('papa', 63),
#  ('sha', 63),
#  ('body', 63),
#  ('never', 62),
#  ('twenty', 62),
#  ('are', 62),
#  ('wen', 62),
#  ('morning', 62),
#  ('banga', 62),
#  ('children', 61),
#  ('learn', 61),
#  ('meet', 61),
#  ('Pidgin', 60),
#  ('ask', 58),
#  ('Jesus', 58),
#  ('her', 57),
#  ('which', 57),
#  ('market', 57),
#  ('who', 57),
#  ('years', 57),
#  ('fact', 56),
#  ('!//=', 56),
#  ('yes', 55),
#  ('find', 55),
#  ('tin', 55),
#  ('waka', 54),
#  ('kill', 54),
#  ('every', 54),
#  ('sabi', 53),
#  ('hm', 53),
#  ('speak', 53),
#  ('change', 53),
#  ('side', 52),
#  ('sell', 52),
#  ('ehm', 52),
#  ('oil', 52),
#  ('six', 51),
#  ('write', 51),
#  ('must', 51),
#  ('maybe', 51),
#  ('dese', 51),
#  ('boil', 51),
#  ('girl', 50),
#  ('drink', 49),
#  ('oga', 48),
#  ('king', 48),
#  ('number', 47),
#  ('fish', 47),
#  ('government', 47),
#  ('animal', 47),
#  ('teach', 46),
#  ('sleep', 46),
#  ('someting', 46),
#  ('head', 45),
#  ('men', 45),
#  ('story', 45),
#  ('mah', 45),
#  ('fire', 45),
#  ('pray', 44),
#  ('State', 44),
#  ('seven', 44),
#  ('outside', 44),
#  ('abi', 44),
#  ('ground', 44),
#  ('open', 43),
#  ('turn', 43),
#  ('everything', 43),
#  ('much', 43),
#  ('tins', 43),
#  ('have', 43),
#  ('English', 42),
#  ('same', 42),
#  ('not', 42),
#  ('bad', 42),
#  ('church', 42),
#  ('tyre', 42),
#  ('grow', 41),
#  ('also', 41),
#  ('run', 41),
#  ('mey', 41),
#  ('next', 41),
#  ('motor', 41),
#  ('fifty', 41),
#  ('die', 40),
#  ('four', 40),
#  ('road', 40),
#  ('once', 40),
#  ('show', 40),
#  ('since', 40),
#  ('nine', 40),
#  ('remember', 40),
#  ('the', 40),
#  ('wait', 39),
#  ('power', 39),
#  ('moh', 39),
#  ('level', 38),
#  ('read', 38),
#  ('old', 38),
#  ('light', 38),
#  ('ten', 37),
#  ('wahala', 37),
#  ('noting', 37),
#  ('pepper', 37),
#  ('suffer', 36),
#  ('abeg', 36),
#  ('pour', 36),
#  ('Pepper', 36),
#  ('sister', 35),
#  ('aha', 35),
#  ('catch', 35),
#  ('leaf', 35),
#  ('Alaska', 35),
#  ('Lagos', 34),
#  ('sweet', 34),
#  ('more', 34),
#  ('rice', 34),
#  ('till', 34),
#  ('wash', 33),
#  ('stop', 33),
#  ('send', 33),
#  ('travel', 33),
#  ('//)', 33),
#  ('month', 33),
#  ('Jos', 33),
#  ('watch', 32),
#  ('right', 32),
#  ('wheder', 32),
#  ('Abuja', 32),
#  ('join', 32),
#  ('check', 32),
#  ('become', 32),
#  ('night', 32),
#  ('pot', 32),
#  ('uncle', 32),
#  ('easy', 31),
#  ('job', 31),
#  ('sit', 31),
#  ('really', 31),
#  ('business', 31),
#  ('add', 31),
#  ('move', 31),
#  ('area', 31),
#  ('starch', 31),
#  ('cut', 31),
#  ('tomorrow', 31),
#  ('mean', 31),
#  ('meat', 31),
#  ('months', 31),
#  ('marry', 30),
#  ('anoda', 30),
#  ('young', 30),
#  ('into', 30),
#  ('friend', 30),
#  ('hot', 30),
#  ('fall', 30),
#  ('least', 29),
#  ('car', 29),
#  ('eight', 29),
#  ('live', 29),
#  ('phone', 29),
#  ('insurance', 29),
#  ('mind', 28),
#  ('oda', 28),
#  ('tink', 28),
#  ('wake', 28),
#  ('husband', 28),
#  ('village', 28),
#  ('enjoy', 28),
#  ('//+', 28),
#  ('cause', 27),
#  ('oh', 27),
#  ('most', 27),
#  ('believe', 27),
#  ('what', 27),
#  ('week', 27),
#  ('ma', 26),
#  ('university', 26),
#  ('hospital', 26),
#  ('cloth', 26),
#  ('hard', 25),
#  ('family', 25),
#  ('sense', 25),
#  ('admission', 25),
#  ('continue', 25),
#  ('love', 25),
#  ('form', 25),
#  ('girls', 25),
#  ('Oga', 25),
#  ('shop', 24),
#  ('WAEC', 24),
#  ('beg', 24),
#  ('ninety', 24),
#  ('around', 24),
#  ('fine', 24),
#  ('wife', 24),
#  ('far', 24),
#  ('eye', 24),
#  ('tank', 24),
#  ('everywhere', 24),
#  ('thirty', 24),
#  ('broder', 24),
#  ('secondary', 23),
#  ('worry', 23),
#  ('face', 23),
#  ('minutes', 23),
#  ('feel', 23),
#  ('was', 23),
#  ('moder', 23),
#  ('sure', 23),
#  ('always', 23),
#  ('oya', 23),
#  ('until', 23),
#  ('keep', 23),
#  ('days', 23),
#  ('weh', 23),
#  ('point', 23),
#  ('palm', 23),
#  ('long', 22),
#  ('anybody', 22),
#  ('close', 22),
#  ('office', 22),
#  ('pick', 22),
#  ('beat', 22),
#  ('vex', 22),
#  ('nobody', 22),
#  ('Nigerian', 22),
#  ('?//=', 22),
#  ('pack', 22),
#  ('em', 22),
#  ('protect', 22),
#  ('ni', 22),
#  ('salt', 22),
#  ('kingdom', 22),
#  ('sometimes', 21),
#  ('later', 21),
#  ('over', 21),
#  ('Naija', 21),
#  ('let', 21),
#  ('egusi', 21),
#  ('together', 21),
#  ('pedal', 21),
#  ('ones', 20),
#  ('parents', 20),
#  ('anywhere', 20),
#  ('anything', 20),
#  ('ball', 20),
#  ('everyday', 20),
#  ('police', 20),
#  ('allow', 20),
#  ('sing', 20),
#  ('dry', 20),
#  ('leg', 20),
#  ('tire', 20),
#  ('hey', 20),
#  ('rest', 20),
#  ('ready', 20),
#  ('obodo', 20),
#  ('togeder', 20),
#  ('million', 20),
#  ('hold', 20),
#  ('weather', 20),
#  ('Presido', 20),
#  ('sin', 20),
#  ('s-', 19),
#  ('primary', 19),
#  ('can', 19),
#  ('happy', 19),
#  ('reason', 19),
#  ('language', 19),
#  ('word', 19),
#  ('home', 19),
#  ('swallow', 19),
#  ('pocket', 19),
#  ('yesterday', 19),
#  ('fuel', 19),
#  ('land', 19),
#  ('world', 19),
#  ('build', 19),
#  ('something', 19),
#  ('babe', 19),
#  ('mysef', 19),
#  ('Buhari', 19),
#  ('new', 19),
#  ('poor', 19),
#  ('shoot', 19),
#  ('festival', 19),
#  ('farm', 19),
#  ('teacher', 18),
#  ('study', 18),
#  ('gree', 18),
#  ('wonder', 18),
#  ('best', 18),
#  ('Wazobia', 18),
#  ('X', 18),
#  ('mouth', 18),
#  ('laugh', 18),
#  ('taste', 18),
#  ('drive', 18),
#  ('yourself', 18),
#  ('hustle', 18),
#  ('prepare', 18),
#  ('egg', 18),
#  ('zero', 18),
#  ('fader', 18),
#  ('full', 18),
#  ('Warri', 18),
#  ('forward', 18),
#  ('sick', 18),
#  ('letter', 18),
#  ('tori', 18),
#  ('book', 17),
#  ('win', 17),
#  ('listen', 17),
#  ('anyhow', 17),
#  ('report', 17),
#  ('issue', 17),
#  ('madam', 17),
#  ('forget', 17),
#  ('ghetto', 17),
#  ('lie', 17),
#  ('almost', 17),
#  ('sharp', 17),
#  ('okra', 17),
#  ('front', 17),
#  ('according', 17),
#  ('price', 17),
#  ('alright', 17),
#  ('investment', 17),
#  ('stir', 17),
#  ('soap', 17),
#  ('quick', 16),
#  ('manage', 16),
#  ('early', 16),
#  ('second', 16),
#  ('yoursef', 16),
#  ("dat's", 16),
#  ('oursef', 16),
#  ('kai', 16),
#  ('weeks', 16),
#  ('touch', 16),
#  ('Mama', 16),
#  ('true', 16),
#  ('under', 16),
#  ('pound', 16),
#  ('haha', 16),
#  ('January', 16),
#  ('serve', 16),
#  ('bitter', 16),
#  ('town', 16),
#  ('local', 16),
#  ('drum', 16),
#  ('Federal', 16),
#  ('site', 16),
#  ('cheat', 16),
#  ('class', 15),
#  ('belle', 15),
#  ('JAMB', 15),
#  ('times', 15),
#  ('Government', 15),
#  ('gats', 15),
#  ('end', 15),
#  ("don't", 15),
#  ('think', 15),
#  ('brain', 15),
#  ('thank', 15),
#  ('already', 15),
#  ('chicken', 15),
#  ('f-', 15),
#  ('news', 15),
#  ('whole', 15),
#  ('colour', 15),
#  ('sixty', 15),
#  ('vote', 15),
#  ('forty', 15),
#  ('sew', 15),
#  ('peace', 15),
#  ('youth', 15),
#  ('correct', 15),
#  ('fruit', 15),
#  ('through', 15),
#  ('done', 15),
#  ("o'clock", 14),
#  ('near', 14),
#  ('stand', 14),
#  ('part', 14),
#  ('fear', 14),
#  ('means', 14),
#  ('increase', 14),
#  ('spoil', 14),
#  ('radio', 14),
#  ('afternoon', 14),
#  ('Baba', 14),
#  ('plan', 14),
#  ('season', 14),
#  ('bless', 14),
#  ('hair', 14),
#  ('blow', 14),
#  ('serious', 13),
#  ('rich', 13),
#  ('bus', 13),
#  ('wheda', 13),
#  ('dough', 13),
#  ('respect', 13),
#  ('service', 13),
#  ('age', 13),
#  ('boys', 13),
#  ("'m", 13),
#  ('climb', 13),
#  ('native', 13),
#  ('create', 13),
#  ('station', 13),
#  ('Benin', 13),
#  ('while', 13),
#  ('dan', 13),
#  ('mix', 13),
#  ('shey', 13),
#  ('myself', 13),
#  ("it's", 13),
#  ('<+', 13),
#  ('programme', 13),
#  ('Friday', 13),
#  ('palace', 13),
#  ('bush', 13),
#  ('Malaysia', 13),
#  ('remain', 13),
#  ('cheap', 13),
#  ('cost', 13),
#  ('yam', 13),
#  ('Delta', 13),
#  ('tory', 13),
#  ('that', 13),
#  ('bow', 13),
#  ('leaders', 13),
#  ('stone', 13),
#  ('gader', 13),
#  ('barrack', 13),
#  ('Christmas', 13),
#  ('Ewere', 13),
#  ('Plateau', 13),
#  ('acha', 13),
#  ('temptation', 13),
#  ('borrow', 13),
#  ('opportunity', 13),
#  ('forgive', 13),
#  ('hope', 12),
#  ('door', 12),
#  ('wrong', 12),
#  ('imsef', 12),
#  ('somebody', 12),
#  ('places', 12),
#  ('important', 12),
#  ('Igbo', 12),
#  ('everytime', 12),
#  ('media', 12),
#  ('miss', 12),
#  ('garri', 12),
#  ('nna', 12),
#  ('drop', 12),
#  ('machine', 12),
#  ('beer', 12),
#  ('evening', 12),
#  ('bill', 12),
#  ('eba', 12),
#  ('hehe', 12),
#  ('wear', 12),
#  ('fresh', 12),
#  ("n't", 12),
#  ('New', 12),
#  ('America', 12),
#  ('beautiful', 12),
#  ('eyes', 12),
#  ('grind', 12),
#  ('graduate', 12),
#  ('seventeen', 12),
#  ('FM', 12),
#  ('each', 12),
#  ('room', 12),
#  ('soldier', 12),
#  ('save', 12),
#  ('being', 12),
#  ('except', 12),
#  ('spirit', 12),
#  ('gote', 12),
#  ('receive', 12),
#  ('TV', 12),
#  ('thick', 12),
#  ('friends', 11),
#  ('dress', 11),
#  ('rush', 11),
#  ('bag', 11),
#  ('prayer', 11),
#  ('infact', 11),
#  ('high', 11),
#  ('Edo', 11),
#  ('state', 11),
#  ('music', 11),
#  ('human', 11),
#  ('nothing', 11),
#  ('Nigerians', 11),
#  ('strong', 11),
#  ('struggle', 11),
#  ('ehe', 11),
#  ('free', 11),
#  ('daughter', 11),
#  ('beans', 11),
#  ('ladies', 11),
#  ('China', 11),
#  ('plus', 11),
#  ('remove', 11),
#  ('bread', 11),
#  ('South', 11),
#  ('paper', 11),
#  ('ear', 11),
#  ('base', 11),
#  ('interview', 11),
#  ('register', 11),
#  ('leaves', 11),
#  ('kunu', 11),
#  ('cry', 10),
#  ('arrange', 10),
#  ('PhD', 10),
#  ('concern', 10),
#  ('nineteen', 10),
#  ('enough', 10),
#  ('course', 10),
#  ('flow', 10),
#  ('street', 10),
#  ('push', 10),
#  ('dance', 10),
#  ('Wednesday', 10),
#  ('social', 10),
#  ('main', 10),
#  ('river', 10),
#  ('rain', 10),
#  ('message', 10),
#  ('clever', 10),
#  ('carrot', 10),
#  ('apart', 10),
#  ('trust', 10),
#  ('future', 10),
#  ('produce', 10),
#  ('patapata', 10),
#  ('loss', 10),
#  ('ingredients', 10),
#  ('fry', 10),
#  ('pounded', 10),
#  ('card', 10),
#  ('tay', 10),
#  ('cover', 10),
#  ('countries', 10),
#  ('scatter', 10),
#  ('National', 10),
#  ('during', 10),
#  ('senior', 10),
#  ('quarrel', 10),
#  ('straight', 10),
#  ('package', 10),
#  ('jump', 10),
#  ('group', 10),
#  ('extend', 10),
#  ('pump', 10),
#  ('anytime', 10),
#  ('method', 10),
#  ('little', 10),
#  ('Bible', 10),
#  ('mehn', 10),
#  ('self', 10),
#  ('guys', 10),
#  ('lecture', 10),
#  ('Africa', 10),
#  ('kerosine', 10),
#  ('tempt', 10),
#  ('Satan', 10),
#  ('advise', 10),
#  ('suspect', 10),
#  ('plate', 9),
#  ('greet', 9),
#  ('dream', 9),
#  ('hunger', 9),
#  ('against', 9),
#  ('third', 9),
#  ('calm', 9),
#  ('gist', 9),
#  ('actually', 9),
#  ('air', 9),
#  ('type', 9),
#  ('treat', 9),
#  ('Port', 9),
#  ('average', 9),
#  ('compare', 9),
#  ('fight', 9),
#  ('charity', 9),
#  ('care', 9),
#  ('twelve', 9),
#  ('grace', 9),
#  ('doctor', 9),
#  ('medicine', 9),
#  ('Oyibo', 9),
#  ('knack', 9),
#  ('sign', 9),
#  ('preach', 9),
#  ('break', 9),
#  ('pursue', 9),
#  ('spend', 9),
#  ('percent', 9),
#  ('relax', 9),
#  ('real', 9),
#  ('prophet', 9),
#  ('truth', 9),
#  ('lawyer', 9),
#  ('salary', 9),
#  ('jam', 9),
#  ('thief', 9),
#  ('bros', 9),
#  ('return', 9),
#  ('examination', 9),
#  ('election', 9),
#  ('short', 9),
#  ('mile', 9),
#  ('Muhammed', 9),
#  ('politics', 9),
#  ('Mr', 9),
#  ('ontop', 9),
#  ('Stout', 9),
#  ('though', 9),
#  ('clean', 9),
#  ('section', 9),
#  ('everytin', 9),
#  ('trouble', 9),
#  ('club', 9),
#  ('per', 9),
#  ('needle', 9),
#  ('immunisation', 9),
#  ('tribe', 9),
#  ('France', 9),
#  ('invest', 9),
#  ('Senate', 9),
#  ('chips', 9),
#  ('judge', 9),
#  ('crayfish', 9),
#  ('dog', 9),
#  ('mortar', 9),
#  ('hotel', 9),
#  ('whistle', 9),
#  ('sotay', 8),
#  ('younger', 8),
#  ('grade', 8),
#  ('wo-', 8),
#  ('complain', 8),
#  ('achieve', 8),
#  ('burn', 8),
#  ('picture', 8),
#  ('draw', 8),
#  ('sometime', 8),
#  ('handle', 8),
#  ('Oyinbo', 8),
#  ('lot', 8),
#  ('may', 8),
#  ('doctors', 8),
#  ('cross', 8),
#  ('experience', 8),
#  ('step', 8),
#  ('tear', 8),
#  ('AC', 8),
#  ('junior', 8),
#  ('fetch', 8),
#  ('white', 8),
#  ('red', 8),
#  ('omo', 8),
#  ('eighteen', 8),
#  ('yeah', 8),
#  ('company', 8),
#  ('cube', 8),
#  ('decide', 8),
#  ('meanwhile', 8),
#  ('ATM', 8),
#  ('promise', 8),
#  ('warn', 8),
#  ('hungry', 8),
#  ('gentlemen', 8),
#  ('b-', 8),
#  ('gather', 8),
#  ('brother', 8),
#  ('train', 8),
#  ('maths', 8),
#  ('solve', 8),
#  ('compound', 8),
#  ('set', 8),
#  ('Sunday', 8),
#  ('sometin', 8),
#  ('wa', 8),
#  ('shawarma', 8),
#  ('Kaduna', 8),
#  ('goat', 8),
#  ('maggi', 8),
#  ('alone', 8),
#  ('Ibadan', 8),
#  ('engine', 8),
#  ('period', 8),
#  ('puh', 8),
#  ('cable', 8),
#  ('connect', 8),
#  ('accept', 8),
#  ('baby', 8),
#  ('choose', 8),
#  ('without', 8),
#  ('makeup', 8),
#  ('attack', 8),
#  ('ogbonno', 8),
#  ('withdraw', 8),
#  ('feminist', 8),
#  ('restaurant', 8),
#  ('ICAN', 8),
#  ('masa', 8),
#  ('cocoyam', 8),
#  ('smooth', 8),
#  ('liters', 8),
#  ('career', 8),
#  ('seminar', 8),
#  ('explain', 7),
#  ('corner', 7),
#  ('pain', 7),
#  ('late', 7),
#  ('law', 7),
#  ('worst', 7),
#  ('drag', 7),
#  ('between', 7),
#  ('funny', 7),
#  ('history', 7),
#  ('research', 7),
#  ('building', 7),
#  ('would', 7),
#  ('chook', 7),
#  ('&?//', 7),
#  ('troway', 7),
#  ('studio', 7),
#  ('post', 7),
#  ('fellow', 7),
#  ('imagine', 7),
#  ('Kpangolo', 7),
#  ('loud', 7),
#  ('confirm', 7),
#  ('ajebo', 7),
#  ('smoke', 7),
#  ('engineering', 7),
#  ('shebi', 7),
#  ('ba', 7),
#  ('hide', 7),
#  ('shout', 7),
#  ('plant', 7),
#  ('instead', 7),
#  ('February', 7),
#  ('December', 7),
#  ('Malay', 7),
#  ('affect', 7),
#  ('weda', 7),
#  ('sickness', 7),
#  ('melon', 7),
#  ('example', 7),
#  ('sack', 7),
#  ('blood', 7),
#  ('London', 7),
#  ('depend', 7),
#  ('oders', 7),
#  ('thirteen', 7),
#  ('sama', 7),
#  ('School', 7),
#  ('fix', 7),
#  ('final', 7),
#  ('Monday', 7),
#  ('yarnings', 7),
#  ('nowadays', 7),
#  ('develop', 7),
#  ('tree', 7),
#  ('monkey', 7),
#  ('other', 7),
#  ('medical', 7),
#  ('resume', 7),
#  ('Facebook', 7),
#  ("a'ah", 7),
#  ('date', 7),
#  ('cow', 7),
#  ('were', 7),
#  ...]

# %%
for token, count_fail in Counter(list(df_deprel[df_deprel["succeed_deprel"] == 0]["token_dep"])).most_common():
    print(token, count_fail, "{:.0f}%".format(100*count_fail/ctr_all_words[token]))
# Out:
# for 278 16%
# dey 251 7%
# to 215 25%
# like 119 22%
# go 117 4%
# sey 117 8%
# now 104 15%
# na 71 4%
# make 69 10%
# be 67 7%
# one 63 8%
# as 63 13%
# of 56 8%
# in 56 25%
# wey 55 4%
# inside 49 17%
# say 47 7%
# on 47 21%
# so 45 4%
# two 43 26%
# me 42 5%
# dat 40 5%
# come 39 6%
# con 37 4%
# know 37 8%
# people 36 8%
# don 36 5%
# five 36 27%
# get 33 5%
# you 33 1%
# all 30 9%
# because 29 8%
# from 29 12%
# e 29 2%
# wetin 28 7%
# no 28 2%
# time 27 13%
# dem 27 3%
# dere 27 13%
# day 27 22%
# do 25 3%
# if 25 4%
# im 23 3%
# nine 22 55%
# see 22 5%
# we 22 2%
# wan 21 6%
# by 21 26%
# I 21 1%
# am 20 2%
# dis 20 2%
# naira 20 22%
# how 19 9%
# God 19 7%
# three 18 19%
# meh 17 9%
# twenty 17 27%
# take 16 5%
# when 16 5%
# man 16 8%
# a 16 10%
# den 16 9%
# outside 16 36%
# who 16 28%
# give 16 7%
# with 16 14%
# di 16 1%
# why 15 15%
# is 15 11%
# ninety 15 62%
# money 15 5%
# Nigeria 15 13%
# wit 14 16%
# person 14 7%
# own 14 10%
# year 14 17%
# o 14 2%
# top 14 17%
# small 13 6%
# morning 13 21%
# six 13 25%
# place 13 10%
# Alaska 13 37%
# ting 12 5%
# bitter 12 75%
# thousand 12 16%
# woman 11 11%
# reach 11 9%
# number 11 23%
# my 11 1%
# way 11 14%
# over 11 52%
# about 11 10%
# buy 11 6%
# zero 11 61%
# here 11 7%
# will 11 16%
# four 10 25%
# carry 10 3%
# pass 10 10%
# talk 10 3%
# which 10 18%
# call 10 5%
# hundred 10 15%
# eh 10 2%
# work 10 3%
# de 10 1%
# far 10 42%
# up 10 7%
# sha 10 16%
# some 10 4%
# fifty 10 24%
# cheat 10 62%
# chop 9 8%
# men 9 20%
# oga 9 19%
# put 9 3%
# today 9 13%
# where 9 7%
# meet 9 15%
# fit 9 2%
# Baba 9 64%
# seven 9 20%
# old 8 21%
# wheder 8 25%
# kind 8 5%
# X 8 44%
# women 8 11%
# till 8 24%
# okay 8 5%
# ni 8 36%
# pounded 8 80%
# obodo 8 40%
# State 8 18%
# born 7 10%
# finish 7 8%
# after 7 7%
# well 7 2%
# just 7 2%
# abi 7 16%
# boy 7 10%
# what 7 26%
# mey 7 17%
# but 7 2%
# car 7 24%
# guy 7 8%
# your 7 1%
# bring 7 9%
# tell 7 2%
# ehn 7 2%
# better 7 8%
# una 7 3%
# seventeen 7 58%
# sick 7 39%
# before 7 5%
# thirty 7 29%
# and 7 1%
# collect 7 10%
# months 7 23%
# mehn 7 70%
# quick 6 38%
# sleep 6 13%
# wheda 6 46%
# down 6 7%
# play 6 9%
# around 6 25%
# Pidgin 6 10%
# children 6 10%
# since 6 15%
# sweet 6 18%
# at 6 5%
# life 6 4%
# look 6 5%
# under 6 38%
# anyting 6 9%
# week 6 22%
# papa 6 10%
# i 6 100%
# Malay 6 86%
# dan 6 46%
# back 6 4%
# tings 6 4%
# National 6 60%
# yarn 6 8%
# our 6 3%
# Naija 6 29%
# Federal 6 38%
# animal 6 13%
# near 6 43%
# more 6 18%
# ground 6 14%
# alias 6 86%
# die 5 12%
# ah 5 2%
# matter 5 7%
# nineteen 5 50%
# report 5 29%
# clock 5 83%
# + 5 100%
# never 5 8%
# catch 5 14%
# eat 5 8%
# drink 5 10%
# much 5 12%
# means 5 36%
# ready 5 25%
# good 5 4%
# oder 5 8%
# country 5 5%
# thing 5 6%
# fuel 5 26%
# touch 5 31%
# show 5 12%
# Wednesday 5 50%
# years 5 9%
# straight 5 50%
# mama 5 6%
# true 5 31%
# start 5 4%
# Stadium 5 100%
# learn 5 8%
# school 5 2%
# mahnsef 5 100%
# tori 5 28%
# base 5 45%
# kuma 5 71%
# Ewere 5 38%
# everybody 4 4%
# s 4 100%
# against 4 44%
# tink 4 14%
# comot 4 3%
# least 4 14%
# must 4 8%
# first 4 4%
# open 4 9%
# Oyibo 4 44%
# too 4 3%
# win 4 24%
# join 4 12%
# motor 4 10%
# cut 4 13%
# ehen 4 4%
# many 4 5%
# close 4 18%
# full 4 22%
# hard 4 16%
# need 4 4%
# mean 4 13%
# f- 4 27%
# square 4 100%
# send 4 12%
# point 4 17%
# U 4 80%
# weeks 4 25%
# sixty 4 27%
# price 4 24%
# soldier 4 33%
# house 4 2%
# hot 4 13%
# dose 4 4%
# patapata 4 40%
# bad 4 10%
# best 4 22%
# eight 4 14%
# ma 4 15%
# things 4 6%
# enter 4 3%
# human 4 36%
# until 4 17%
# Christmas 4 31%
# Ash 4 100%
# through 4 27%
# wen 4 6%
# easy 4 13%
# Oga 4 16%
# League 4 67%
# fourteen 4 67%
# girl 4 8%
# dot 4 80%
# plenty 4 6%
# banga 4 6%
# caustic 4 100%
# wash 4 12%
# agric 4 67%
# whistle 4 44%
# insha 4 100%
# chapter 4 100%
# verse 4 80%
# pikin 3 3%
# last 3 5%
# s- 3 16%
# rich 3 23%
# late 3 43%
# worst 3 43%
# than 3 75%
# World 3 100%
# between 3 43%
# bah 3 50%
# read 3 8%
# also 3 7%
# hand 3 4%
# post 3 43%
# fish 3 6%
# are 3 5%
# shey 3 23%
# understand 3 5%
# t- 3 60%
# market 3 5%
# sometime 3 38%
# proud 3 100%
# boil 3 6%
# very 3 2%
# hear 3 3%
# omo 3 38%
# month 3 9%
# wella 3 60%
# December 3 43%
# crush 3 100%
# most 3 11%
# poor 3 16%
# that 3 23%
# Papa 2 50%
# President 2 50%
# Oko 2 50%
# Congress 2 100%
# bow 2 15%
# General 2 50%
# arrange 2 20%
# re 2 50%
# Lagelu 2 33%
# Buhari 2 11%
# Mama 2 12%
# corn 2 50%
# bride 2 100%
# anoder 2 3%
# togeder 2 10%
# everywhere 2 8%
# everytime 2 17%
# valuable 2 67%
# Moder 2 100%
# remain 2 15%
# out 2 2%
# Ministry 2 40%
# South 2 18%
# bold 2 100%
# gree 2 11%
# temperature 2 100%
# except 2 17%
# period 2 25%
# soldiers 2 29%
# shoot 2 11%
# anybody 2 9%
# days 2 9%
# road 2 5%
# seventy 2 33%
# few 2 67%
# New 2 17%
# leaf 2 6%
# sing 2 10%
# wake 2 7%
# evil 2 67%
# interesting 2 33%
# story 2 4%
# move 2 6%
# level 2 5%
# fast 2 29%
# step 2 25%
# suppose 2 3%
# Jonathan 2 33%
# politics 2 22%
# any 2 2%
# family 2 8%
# sabi 2 4%
# try 2 2%
# pour 2 6%
# himsef 2 33%
# Capital 2 67%
# forward 2 11%
# wahala 2 5%
# sewing 2 67%
# front 2 12%
# wid 2 100%
# waka 2 4%
# Baptist 2 100%
# Hausa 2 40%
# gain 2 33%
# cos 2 40%
# leaders 2 15%
# example 2 29%
# oil 2 4%
# push 2 20%
# merry 2 100%
# daughter 2 18%
# credit 2 50%
# hey 2 10%
# begin 2 3%
# high 2 18%
# sin 2 10%
# grace 2 22%
# NISER 2 100%
# Park 2 50%
# shame 2 50%
# bele 2 40%
# cause 2 7%
# both 2 40%
# difference 2 29%
# according 2 12%
# Senate 2 22%
# judge 2 22%
# pump 2 20%
# da 2 67%
# including 2 40%
# Super 2 67%
# Manchester 2 67%
# moder 2 9%
# ogbonno 2 25%
# everything 2 5%
# graduate 2 17%
# broder 2 8%
# Queen 2 100%
# Sir 2 50%
# yoursef 2 12%
# dad 2 67%
# fact 2 4%
# pay 2 2%
# check 2 6%
# even 2 1%
# Cain 2 40%
# government 2 4%
# aside 2 67%
# beautiful 2 17%
# ontop 2 22%
# world 2 11%
# public 2 67%
# something 2 11%
# sure 2 9%
# France 2 22%
# Wazobia 2 11%
# seat 2 29%
# sake 2 33%
# Central 2 67%
# reason 2 11%
# 's 2 67%
# become 2 6%
# material 2 67%
# serve 2 12%
# book 2 12%
# senior 2 20%
# sit 2 6%
# acha 2 15%
# Berom 2 33%
# Jos 2 6%
# Niger 2 67%
# soup 2 2%
# mortar 2 22%
# sharp 2 12%
# husband 2 7%
# sulphuric 2 33%
# stir 2 12%
# soda 2 29%
# ash 2 67%
# fader 2 11%
# use 2 1%
# Porico 2 100%
# students 2 40%
# budget 2 33%
# foreign 2 100%
# bros 2 22%
# lost 2 40%
# dress 2 18%
# connect 2 25%
# native 2 15%
# beat 2 9%
# village 2 7%
# wah 2 67%
# abeg 2 6%
# eme 2 100%
# ntughari 2 100%
# ladies 2 18%
# Foreign 2 100%
# street 2 20%
# madam 2 12%
# parile 2 100%
# attempt 2 100%
# ATM 2 25%
# gader 2 15%
# pack 2 9%
# Sunshine 2 100%
# Premier 2 100%
# JAMB 2 13%
# East 1 17%
# baddest 1 50%
# Teheran 1 100%
# meanwhile 1 12%
# Islamic 1 100%
# Iran 1 100%
# Senyatuwe 1 100%
# BBC 1 100%
# Hyde 1 100%
# sele 1 17%
# Bafana 1 25%
# Nations 1 100%
# qualifier 1 100%
# clash 1 100%
# Kaiser 1 100%
# Chiefs 1 100%
# SuperSport 1 100%
# coach 1 20%
# set 1 12%
# Eagles 1 100%
# International 1 50%
# fans 1 33%
# Paris 1 50%
# Cavani 1 50%
# La 1 50%
# semifinal 1 100%
# courtesy 1 100%
# Famyes 1 100%
# England 1 50%
# mid 1 100%
# goalless 1 100%
# Arsenal 1 25%
# wanted 1 100%
# Guinea 1 100%
# Ireland 1 100%
# lala 1 100%
# Stoke 1 100%
# Ozil 1 100%
# Germany 1 33%
# Emirate 1 100%
# tier 1 100%
# Numancia 1 100%
# Madrid 1 33%
# brake 1 100%
# Aposu 1 100%
# upon 1 20%
# name 1 1%
# Nicodemus 1 17%
# blind 1 50%
# along 1 33%
# Again 1 100%
# heaven 1 17%
# change 1 2%
# cannot 1 25%
# changed 1 100%
# tomorrow 1 3%
# headache 1 25%
# kingdom 1 5%
# access 1 100%
# funny 1 14%
# round 1 25%
# calling 1 33%
# career 1 12%
# piloting 1 50%
# fly 1 17%
# smart 1 50%
# Pay 1 100%
# real 1 11%
# mentorship 1 100%
# ma-firewood 1 100%
# com 1 100%
# China 1 9%
# made 1 100%
# p.m. 1 25%
# pm 1 100%
# gbangain 1 100%
# Aztech 1 50%
# Event 1 100%
# Hotel 1 100%
# scatter 1 10%
# MTN 1 100%
# discipline 1 50%
# ambassador 1 100%
# secure 1 100%
# Sunday 1 12%
# figures 1 100%
# income 1 100%
# thereabout 1 100%
# text 1 33%
# Wilson 1 100%
# Tea 1 100%
# Mate 1 100%
# Bread 1 100%
# Presidential 1 50%
# oya 1 4%

# %%
ctr_all_words[token]

# %%
df_deprel[df_deprel["succeed_deprel"] == 0].groupby("token_dep").sum()
# Out:
#            succeed_deprel  succeed_head
# token_dep
# !//=                    0             1
# ##                      0             0
# &//                     0             0
# 's                      0             0
# *                       0             0
# ...                   ...           ...
# your                    0             2
# yoursef                 0             1
# youths                  0             0
# zero                    0             8
# zuga                    0             0
#
# [1724 rows x 2 columns]

# %%
df_deprel
# Out:
#        deprel_true deprel_pred  succeed_deprel  succeed_head token_head  \
# 0             subj        subj               1             0        dey
# 1              mod        root               0             0       life
# 2         comp:obj    comp:obj               1             1        for
# 3              mod         mod               1             0       life
# 4              mod         mod               1             1      pikin
# ...            ...         ...             ...           ...        ...
# 131037         mod    compound               0             1    version
# 131038    comp:obj    comp:obj               1             1       hear
# 131039         mod         mod               1             1    version
# 131040    comp:obj    comp:obj               1             1         of
# 131041       punct       punct               1             1         na
#
#        token_dep  syn_dist  sequence_len
# 0           life         6            11
# 1            for        -1            11
# 2             me        -1            11
# 3             as        -3            11
# 4          small         1            11
# ...          ...       ...           ...
# 131037   English         1            12
# 131038   version        -3            12
# 131039        of        -1            12
# 131040        me        -1            12
# 131041        //       -11            12
#
# [131042 rows x 8 columns]
